# %%
# @title 🛠️ Setup Environment
# !pip install runpod==1.3.0
print("✅ RunPod SDK installed.")
# Out:
# Collecting runpod==1.3.0
#   Downloading runpod-1.3.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: aiohttp>=3.8.6 in /usr/local/lib/python3.12/dist-packages (from runpod==1.3.0) (3.13.3)
# Collecting aiohttp-retry>=2.8.3 (from runpod==1.3.0)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting backoff==2.2.1 (from runpod==1.3.0)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting boto3>=1.26.165 (from runpod==1.3.0)
#   Downloading boto3-1.42.47-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.12/dist-packages (from runpod==1.3.0) (8.3.1)
# Requirement already satisfied: fastapi>=0.94.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.3.0) (0.128.2)
# Requirement already satisfied: pillow>=9.5.0 in /usr/local/lib/python3.12/dist-packages (from runpod==1.3.0) (11.3.0)
# Requirement already satisfied: py-cpuinfo==9.0.0 in /usr/local/lib/python3.12/dist-packages (from runpod==1.3.0) (9.0.0)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from runpod==1.3.0) (1.2.1)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from runpod==1.3.0) (2.32.4)
# Collecting tomli>=2.0.1 (from runpod==1.3.0)
#   Downloading tomli-2.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting tqdm-loggable==0.1.4 (from runpod==1.3.0)
#   Downloading tqdm_loggable-0.1.4-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from runpod==1.3.0) (2.5.0)
# Collecting setuptools-scm==8.0.4 (from runpod==1.3.0)
#   Downloading setuptools_scm-8.0.4-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from setuptools-scm==8.0.4->runpod==1.3.0) (26.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from setuptools-scm==8.0.4->runpod==1.3.0) (75.2.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from setuptools-scm==8.0.4->runpod==1.3.0) (4.15.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in /usr/local/lib/python3.12/dist-packages (from tqdm-loggable==0.1.4->runpod==1.3.0) (4.67.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.6->runpod==1.3.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.6->runpod==1.3.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.6->runpod==1.3.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.6->runpod==1.3.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.6->runpod==1.3.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.6->runpod==1.3.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.6->runpod==1.3.0) (1.22.0)
# Collecting botocore<1.43.0,>=1.42.47 (from boto3>=1.26.165->runpod==1.3.0)
#   Downloading botocore-1.42.47-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.26.165->runpod==1.3.0)
#   Downloading jmespath-1.1.0-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3>=1.26.165->runpod==1.3.0)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.94.0->fastapi[all]>=0.94.0->runpod==1.3.0) (0.50.0)
# Requirement already satisfied: pydantic>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.94.0->fastapi[all]>=0.94.0->runpod==1.3.0) (2.12.3)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.94.0->fastapi[all]>=0.94.0->runpod==1.3.0) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.94.0->fastapi[all]>=0.94.0->runpod==1.3.0) (0.0.4)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0)
#   Downloading fastapi_cli-0.0.21-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.3.0) (0.28.1)
# Requirement already satisfied: jinja2>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.3.0) (3.1.6)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.3.0) (0.0.22)
# Requirement already satisfied: itsdangerous>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.3.0) (2.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.3.0) (6.0.3)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi[all]>=0.94.0->runpod==1.3.0)
#   Downloading ujson-5.11.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (9.4 kB)
# Requirement already satisfied: orjson>=3.2.1 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.3.0) (3.11.7)
# Collecting email-validator>=2.0.0 (from fastapi[all]>=0.94.0->runpod==1.3.0)
#   Downloading email_validator-2.3.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (0.40.0)
# Requirement already satisfied: pydantic-settings>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[all]>=0.94.0->runpod==1.3.0) (2.12.0)
# Collecting pydantic-extra-types>=2.0.0 (from fastapi[all]>=0.94.0->runpod==1.3.0)
#   Downloading pydantic_extra_types-2.11.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->runpod==1.3.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->runpod==1.3.0) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->runpod==1.3.0) (2026.1.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.47->boto3>=1.26.165->runpod==1.3.0) (2.9.0.post0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[all]>=0.94.0->runpod==1.3.0)
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typer>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (0.21.1)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0)
#   Downloading rich_toolkit-0.19.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0)
#   Downloading fastapi_cloud_cli-0.11.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.23.0->fastapi[all]>=0.94.0->runpod==1.3.0) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.23.0->fastapi[all]>=0.94.0->runpod==1.3.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->fastapi[all]>=0.94.0->runpod==1.3.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1.5->fastapi[all]>=0.94.0->runpod==1.3.0) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->fastapi>=0.94.0->fastapi[all]>=0.94.0->runpod==1.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.0->fastapi>=0.94.0->fastapi[all]>=0.94.0->runpod==1.3.0) (2.41.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (15.0.1)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0)
#   Downloading rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (2.52.0)
# Collecting fastar>=0.8.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0)
#   Downloading fastar-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.47->boto3>=1.26.165->runpod==1.3.0) (1.17.0)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (13.9.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (1.5.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "all"->fastapi[all]>=0.94.0->runpod==1.3.0) (0.1.2)
# Downloading runpod-1.3.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.1 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading setuptools_scm-8.0.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 2.5 MB/s eta 0:00:00
# Downloading tqdm_loggable-0.1.4-py3-none-any.whl (9.0 kB)
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Downloading boto3-1.42.47-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 6.5 MB/s eta 0:00:00
# Downloading tomli-2.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 kB 15.4 MB/s eta 0:00:00
# Downloading botocore-1.42.47-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 61.0 MB/s eta 0:00:00
# Downloading email_validator-2.3.0-py3-none-any.whl (35 kB)
# Downloading fastapi_cli-0.0.21-py3-none-any.whl (12 kB)
# Downloading jmespath-1.1.0-py3-none-any.whl (20 kB)
# Downloading pydantic_extra_types-2.11.0-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 3.6 MB/s eta 0:00:00
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.2 MB/s eta 0:00:00
# Downloading ujson-5.11.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 4.2 MB/s eta 0:00:00
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 10.4 MB/s eta 0:00:00
# Downloading fastapi_cloud_cli-0.11.0-py3-none-any.whl (26 kB)
# Downloading rich_toolkit-0.19.3-py3-none-any.whl (32 kB)
# Downloading fastar-0.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (821 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.6/821.6 kB 19.2 MB/s eta 0:00:00
# Downloading rignore-0.7.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (959 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 37.8 MB/s eta 0:00:00
# Installing collected packages: ujson, tqdm-loggable, tomli, setuptools-scm, rignore, jmespath, fastar, dnspython, backoff, email-validator, botocore, s3transfer, rich-toolkit, pydantic-extra-types, aiohttp-retry, fastapi-cloud-cli, fastapi-cli, boto3, runpod
# Successfully installed aiohttp-retry-2.9.1 backoff-2.2.1 boto3-1.42.47 botocore-1.42.47 dnspython-2.8.0 email-validator-2.3.0 fastapi-cli-0.0.21 fastapi-cloud-cli-0.11.0 fastar-0.8.0 jmespath-1.1.0 pydantic-extra-types-2.11.0 rich-toolkit-0.19.3 rignore-0.7.6 runpod-1.3.0 s3transfer-0.16.0 setuptools-scm-8.0.4 tomli-2.4.0 tqdm-loggable-0.1.4 ujson-5.11.0
# ✅ RunPod SDK installed.

# %%
# @title 📂 Prepare Test Data
import os
# Create images directory and download a sample
# !mkdir -p images
# !wget -O images/output_liver_segmentation.jpg https://github.com/Oumar199/LiverVolumetry/blob/main/images/output_liver_segmentation.jpg?raw=true
print("✅ Sample image downloaded to images/output_liver_segmentation.jpg.jpg")
# Out:
# --2026-02-11 21:42:04--  https://github.com/Oumar199/LiverVolumetry/blob/main/images/output_liver_segmentation.jpg?raw=true
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/Oumar199/LiverVolumetry/raw/refs/heads/main/images/output_liver_segmentation.jpg [following]
# --2026-02-11 21:42:04--  https://github.com/Oumar199/LiverVolumetry/raw/refs/heads/main/images/output_liver_segmentation.jpg
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/Oumar199/LiverVolumetry/refs/heads/main/images/output_liver_segmentation.jpg [following]
# --2026-02-11 21:42:05--  https://raw.githubusercontent.com/Oumar199/LiverVolumetry/refs/heads/main/images/output_liver_segmentation.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 115902 (113K) [image/jpeg]
# Saving to: ‘images/output_liver_segmentation.jpg’
#
# images/output_liver 100%[===================>] 113.19K  --.-KB/s    in 0.01s
#
# 2026-02-11 21:42:05 (9.00 MB/s) - ‘images/output_liver_segmentation.jpg’ saved [115902/115902]
#
# ✅ Sample image downloaded to images/output_liver_segmentation.jpg.jpg

# %%
# @title 🚀 Run Medgemma Analysis
import runpod
import base64

# Config
ENDPOINT_ID = "0tfhtd7237woyr"
# API_KEY = ""
IMAGE_PATH = "images/output_liver_segmentation.jpg"

def run_demo():
    with open(IMAGE_PATH, 'rb') as f:
        encoded = base64.b64encode(f.read()).decode('utf-8')

    endpoint = runpod.Endpoint(ENDPOINT_ID, api_key=API_KEY)

    print("🛰️ Connecting to RunPod Serverless...")
    try:
        result = endpoint.run({"image": encoded}, 
                            #   timeout=120
                              )
        print("\n📝 --- ANALYSIS RESULTS ---")
        print(result)
    except Exception as e:
        print(f"❌ Error: {e}")

run_demo()
# Out:
# 🛰️ Connecting to RunPod Serverless...
#
# 📝 --- ANALYSIS RESULTS ---
# <runpod.endpoint.runner.Job object at 0x000001F1AE55F910>
