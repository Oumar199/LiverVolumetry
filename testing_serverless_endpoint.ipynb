# %%
import runpod
import base64

# %%
with open("images/output_liver_segmentation.jpg", "rb") as image_file:
    encoded_string = base64.b64encode(image_file.read()).decode("utf-8")

# %%
endpoint = runpod.Endpoint(
    "zdnmv655sdudww", api_key="rpa_5C7ARZ9TEAT21XNBGA9Q16P1H151ODBOVDDU80C92xocxf"
)

try:
    run_request = endpoint.run_sync(
        {"image": encoded_string},
        timeout=120
    )

    print(run_request)
except TimeoutError:
    print("Job timed out.")
